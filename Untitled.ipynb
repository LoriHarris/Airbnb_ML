# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv("listings.csv")

# %%
train.head()
# Out:
#       id                                          name  host_id host_name  \
# 0  10291                 Spacious Cottage in Mid-City!    31004      Jill
# 1  19091                Fully Furnished Cozy Apartment    72880      John
# 2  26834              Maison Mandeville in the Marigny   114452    Rachel
# 3  53173  MARDI GRAS YA’LL HUNDREDS 5 STAR REVIEWS !!!    12154     Karen
# 4  53544      Historical Bywater Mother in Law Cottage   249527       Lee
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0                  NaN       Navarre  29.98666  -90.10928  Entire home/apt
# 1                  NaN      Leonidas  29.96257  -90.11877  Entire home/apt
# 2                  NaN       Marigny  29.96557  -90.05531  Entire home/apt
# 3                  NaN    St. Claude  29.96483  -90.03906     Private room
# 4                  NaN       Bywater  29.96697  -90.03068  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    300               2                 96   2/17/2019               0.99
# 1    100               1                432    3/3/2019               3.99
# 2    125               4                222   2/24/2019               2.10
# 3    115               3                133   2/20/2019               1.32
# 4     50               5                180   1/25/2019               1.76
#
#    calculated_host_listings_count  availability_365
# 0                               1               331
# 1                               1               303
# 2                               2                23
# 3                               2               354
# 4                               2                10

# %%
train.isnull().sum()
# Out:
# id                                   0
# name                                 2
# host_id                              0
# host_name                            0
# neighbourhood_group               6632
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                        613
# reviews_per_month                  613
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
train = train.drop(columns=['host_name','name', 'id', 'host_id', 'neighbourhood_group', 'latitude', 'longitude', 'last_review', 'reviews_per_month'])

# %%
train.head()
# Out:
#   neighbourhood        room_type  price  minimum_nights  number_of_reviews  \
# 0       Navarre  Entire home/apt    300               2                 96
# 1      Leonidas  Entire home/apt    100               1                432
# 2       Marigny  Entire home/apt    125               4                222
# 3    St. Claude     Private room    115               3                133
# 4       Bywater  Entire home/apt     50               5                180
#
#    calculated_host_listings_count  availability_365
# 0                               1               331
# 1                               1               303
# 2                               2                23
# 3                               2               354
# 4                               2                10

# %%
df = train.dropna(how="any")
df.count()
# Out:
# neighbourhood                     6632
# room_type                         6632
# price                             6632
# minimum_nights                    6632
# number_of_reviews                 6632
# calculated_host_listings_count    6632
# availability_365                  6632
# dtype: int64

# %%
df = df.groupby(['neighbourhood']).mean()

# %%
df.head()
# Out:
#                      price  minimum_nights  number_of_reviews  \
# neighbourhood
# Algiers Point   140.786885        2.147541          50.491803
# Audubon         240.122951        3.745902          37.852459
# Bayou St. John  182.477273        3.159091          36.833333
# Behrman         122.750000        1.916667          15.166667
# Black Pearl     147.862069        4.068966          45.931034
#
#                 calculated_host_listings_count  availability_365
# neighbourhood
# Algiers Point                         2.491803        173.114754
# Audubon                               2.254098        155.598361
# Bayou St. John                        2.621212        139.772727
# Behrman                               1.166667        185.583333
# Black Pearl                           3.206897        145.551724

# %%
pd.to_numeric(df['price'])
# Out:
# neighbourhood
# Algiers Point                140.786885
# Audubon                      240.122951
# Bayou St. John               182.477273
# Behrman                      122.750000
# Black Pearl                  147.862069
# Broadmoor                    159.427419
# Bywater                      195.791489
# Central Business District    297.838600
# Central City                 178.569620
# City Park                    190.394737
# Desire Area                  143.000000
# Dillard                      147.685714
# Dixon                         70.333333
# East Carrollton              155.913793
# East Riverside               201.376147
# Fairgrounds                  169.063953
# Fillmore                     196.963636
# Florida Area                 148.571429
# French Quarter               245.471429
# Freret                       156.931818
# Garden District              282.150943
# Gentilly Terrace             138.069307
# Gentilly Woods               152.909091
# Gert Town                    111.375000
# Hollygrove                   151.230769
# Holy Cross                   132.452830
# Iberville                    141.500000
# Irish Channel                196.307087
# Lake Catherine               399.066667
# Lake Terrace & Oaks           97.500000
#                                 ...
# Mcdonogh                     126.484848
# Mid-City                     236.898438
# Milan                        223.915888
# Milneburg                    144.868421
# Navarre                      210.263158
# New Aurora - English Turn    147.625000
# Old Aurora                   186.958333
# Pines Village                212.666667
# Plum Orchard                 138.750000
# Pontchartrain Park           228.714286
# Read Blvd East               292.555556
# Read Blvd West               359.500000
# Seventh Ward                 236.054545
# St.  Anthony                 134.971429
# St. Bernard Area             143.375000
# St. Claude                   142.376033
# St. Roch                     153.192593
# St. Thomas Dev               227.344828
# Tall Timbers - Brechtel      159.454545
# Touro                        188.750000
# Treme - Lafitte              239.863980
# Tulane - Gravier             401.448000
# U.S. Naval Base               79.000000
# Uptown                       251.966667
# Viavant - Venetian Isles      75.000000
# Village De Lest              133.750000
# West End                     152.722222
# West Lake Forest             175.000000
# West Riverside               262.394495
# Whitney                      113.230769
# Name: price, Length: 69, dtype: float64

# %%
price_high = df.loc[(df['price']>=300)]
price_mid = df[(df['price']>150) & (df['price'] <300)]
price_low = df[(df['price']>=0) & (df['price'] <150)]
p_low = price_low.reset_index()

# %%
fig, ax = plt.subplots()
x_axis = np.arange(len(price_low['price']))
ax.bar(x_axis, price_low['price'])
labels =p_low['neighbourhood']
ax.set_xticks(x_axis)
ax.set_xticklabels(labels, rotation=50, ha="right")
# Out:
# [Text(0, 0, 'Algiers Point'),
#  Text(0, 0, 'Behrman'),
#  Text(0, 0, 'Black Pearl'),
#  Text(0, 0, 'Desire Area'),
#  Text(0, 0, 'Dillard'),
#  Text(0, 0, 'Dixon'),
#  Text(0, 0, 'Florida Area'),
#  Text(0, 0, 'Gentilly Terrace'),
#  Text(0, 0, 'Gert Town'),
#  Text(0, 0, 'Holy Cross'),
#  Text(0, 0, 'Iberville'),
#  Text(0, 0, 'Lake Terrace & Oaks'),
#  Text(0, 0, 'Lower Ninth Ward'),
#  Text(0, 0, 'Mcdonogh'),
#  Text(0, 0, 'Milneburg'),
#  Text(0, 0, 'New Aurora - English Turn'),
#  Text(0, 0, 'Plum Orchard'),
#  Text(0, 0, 'St.  Anthony'),
#  Text(0, 0, 'St. Bernard Area'),
#  Text(0, 0, 'St. Claude'),
#  Text(0, 0, 'U.S. Naval Base'),
#  Text(0, 0, 'Viavant - Venetian Isles'),
#  Text(0, 0, 'Village De Lest'),
#  Text(0, 0, 'Whitney')]
