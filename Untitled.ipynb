# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# %%
model_df=pd.DataFrame({'Model Type':['Neutal Network', 'Random Forest', 'Gaussian','Decision Tree','Nearest Neighbors','Support Vector'],'Accuracy':[0.56711, 0.568106,0.457143,0.48478,0.364452,0.340199]})
model_df.keys()
# Out:
# Index(['Model Type', 'Accuracy'], dtype='object')

# %%
fig, ax = plt.subplots()
# fig1, ax1=plt.subplots()
x_axis=np.arange(len(model_df['Model Type']))
ax.grid(zorder=0)

bars=ax.bar(x_axis, model_df['Accuracy'], zorder=3,color='lightsteelblue')
labels=model_df['Model Type']
ax.set_xticks(x_axis)
ax.set_xticklabels(["\n"*(i%2) + l for i,l in enumerate(labels)])
# ax.set_xticklabels(labels, rotation=10,ha="right")
# ax.set_xlabel(x_axis)
bars[1].set_color('aqua')
bars[1].set_edgecolor('black')
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
plt.title('Model Accuracy Results', fontsize=24)
plt.ylabel('Accuracy Percentage', fontsize=16)
plt.xlabel('Model Type', fontsize=16)
plt.legend()
for rect in ax.patches:
    y_value=rect.get_height()
    x_value=rect.get_x() + rect.get_width()/2
    space = -3
    va = "top"
    fs = 10
    fc="black"
    w = "normal"
  
 
        
    label = '{:.2%}'.format(y_value)
             
    plt.annotate(label, (x_value, y_value), xytext=(0, space), textcoords="offset points", ha = "center", va=va, fontsize=fs, color=fc, weight=w)         
    plt.tight_layout()
    plt.savefig('filename.png')
# Out:
# No handles with labels found to put in legend.

# %%
plt.savefig('filename.png')
